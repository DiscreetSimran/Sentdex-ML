# %%
import quandl
import pandas as pd

# %%
#BUILDING DATASET
#api_key is from the quandl acccount and 'FMAC/30US' is the dataset's quandl code which we are importing

quandl.ApiConfig.api_key = 'x1sxcyxyfLTV1Ws2tT7y'
df=quandl.get('FMAC/30US', api_key = 'x1sxcyxyfLTV1Ws2tT7y')

# %%
# here in the o/p the date is already made as the index which is automatic in case of quandl modules

print(df.head)
# Out:
# <bound method NDFrame.head of             Value
# Date
# 1971-04-02   7.33
# 1971-04-09   7.31
# 1971-04-16   7.31
# 1971-04-23   7.31
# 1971-04-30   7.29
# 1971-05-07   7.38
# 1971-05-14   7.42
# 1971-05-21   7.44
# 1971-05-28   7.46
# 1971-06-04   7.52
# 1971-06-11   7.52
# 1971-06-18   7.54
# 1971-06-25   7.54
# 1971-07-02   7.54
# 1971-07-09   7.54
# 1971-07-16   7.60
# 1971-07-23   7.65
# 1971-07-30   7.69
# 1971-08-06   7.66
# 1971-08-13   7.73
# 1971-08-20   7.71
# 1971-08-27   7.69
# 1971-09-03   7.71
# 1971-09-10   7.67
# 1971-09-17   7.70
# 1971-09-24   7.67
# 1971-10-01   7.67
# 1971-10-08   7.63
# 1971-10-15   7.63
# 1971-10-22   7.58
# ...           ...
# 2018-08-30   4.52
# 2018-09-06   4.54
# 2018-09-13   4.60
# 2018-09-20   4.65
# 2018-09-27   4.72
# 2018-10-04   4.71
# 2018-10-11   4.90
# 2018-10-18   4.85
# 2018-10-25   4.86
# 2018-11-01   4.83
# 2018-11-08   4.94
# 2018-11-15   4.94
# 2018-11-21   4.81
# 2018-11-29   4.81
# 2018-12-06   4.75
# 2018-12-13   4.63
# ...

# %%
# now we want to read a table of us states on a wikipedia page  using pandas
# and we already know how to read a HTML file


fiddy_states=pd.read_html('https://en.wikipedia.org/wiki/List_of_U.S._states_and_territories_by_area')

#when we read html .. pd.read() puts the information into a list of data frames
# even though from this website we are only needing the table but it is going to make multiple attempts and reading it
# it might also read other tables besides the table we want (the big one)
# it is going to find all the tables in that page

# %%
print(fiddy_states)

# the o/p begins and ends with a square bracket which signifies a list
# there are 4 data frames in this o/p .. each starting with 0 and we want the first data frame
# Out:
# [                                    0              1             2         3   \
# 0                                  NaN  Total area[2]  Land area[2]  Water[2]
# 1   Statefederal district or territory           Rank         sq mi       km²
# 2                               Alaska            NaN     665384.04   1723337
# 3                                Texas            NaN     268596.46    695662
# 4                           California            NaN     163696.32    423972
# 5                              Montana            NaN     147039.71    380831
# 6                           New Mexico            NaN     121590.30    314917
# 7                              Arizona            NaN     113990.30    295234
# 8                               Nevada            NaN     110571.82    286380
# 9                             Colorado            NaN     104093.67    269601
# 10                              Oregon            NaN      98378.54    254799
# ...

# %%
#for only the first data frame

print(fiddy_states[0])
# Out:
#                                     0              1             2         3   \
# 0                                  NaN  Total area[2]  Land area[2]  Water[2]
# 1   Statefederal district or territory           Rank         sq mi       km²
# 2                               Alaska            NaN     665384.04   1723337
# 3                                Texas            NaN     268596.46    695662
# 4                           California            NaN     163696.32    423972
# 5                              Montana            NaN     147039.71    380831
# 6                           New Mexico            NaN     121590.30    314917
# 7                              Arizona            NaN     113990.30    295234
# 8                               Nevada            NaN     110571.82    286380
# 9                             Colorado            NaN     104093.67    269601
# 10                              Oregon            NaN      98378.54    254799
# ...

# %%
# for the first coloumn of the first dataframe

print(fiddy_states[0][0])
# Out:
# 0                                    NaN
# 1     Statefederal district or territory
# 2                                 Alaska
# 3                                  Texas
# 4                             California
# 5                                Montana
# 6                             New Mexico
# 7                                Arizona
# 8                                 Nevada
# 9                               Colorado
# 10                                Oregon
# 11                               Wyoming
# 12                              Michigan
# 13                             Minnesota
# 14                                  Utah
# 15                                 Idaho
# 16                                Kansas
# 17                              Nebraska
# 18                          South Dakota
# 19                            Washington
# 20                          North Dakota
# 21                              Oklahoma
# 22                              Missouri
# ...

# %%
# now , in the above coloumn ,if we want everything from element 1 till the end because element 0 is not of much use

for abbv in fiddy_states[0][0][1:]:
    print('FMAC/30US ' + str(abbv))
    
#here are all the API names which we want to query for
# instead of FMAC/30US in the print statement we can write any thing
# Out:
# FMAC/30US Statefederal district or territory
# FMAC/30US Alaska
# FMAC/30US Texas
# FMAC/30US California
# FMAC/30US Montana
# FMAC/30US New Mexico
# FMAC/30US Arizona
# FMAC/30US Nevada
# FMAC/30US Colorado
# FMAC/30US Oregon
# FMAC/30US Wyoming
# FMAC/30US Michigan
# FMAC/30US Minnesota
# FMAC/30US Utah
# FMAC/30US Idaho
# FMAC/30US Kansas
# FMAC/30US Nebraska
# FMAC/30US South Dakota
# FMAC/30US Washington
# FMAC/30US North Dakota
# FMAC/30US Oklahoma
# FMAC/30US Missouri
# FMAC/30US Florida
# FMAC/30US Wisconsin
# FMAC/30US Georgia
# FMAC/30US Illinois
# FMAC/30US Iowa
# FMAC/30US New York
# FMAC/30US North Carolina
# FMAC/30US Arkansas
# FMAC/30US Alabama
# FMAC/30US Louisiana
# FMAC/30US Mississippi
# FMAC/30US Pennsylvania
# FMAC/30US Ohio
# FMAC/30US Virginia
# FMAC/30US Tennessee
# FMAC/30US Kentucky
# FMAC/30US Indiana
# FMAC/30US Maine
# FMAC/30US South Carolina
# FMAC/30US West Virginia
# FMAC/30US Maryland
# FMAC/30US Hawaii
# FMAC/30US Massachusetts
# FMAC/30US Vermont
# ...

# %%
#CONCATENATING AND APPENDING DATA FRAMES

df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
concat_string = pd.concat([df1,df2])
print(concat_string)
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
concat_string = pd.concat([df1,df2,df3])
print(concat_string)

#in this output we can merge the indexes if we want .. later shown in the code 
#index 2001-2004 are displayed twice and they could  be easily merged  as values of HPI for 2001-2004 are same both the times
# Out:
#       HPI  Int_rate  Low_tier_HPI  US_GDP_Thousands
# 2001   80         2           NaN              50.0
# 2002   85         3           NaN              55.0
# 2003   88         2           NaN              65.0
# 2004   85         2           NaN              55.0
# 2005   80         2           NaN              50.0
# 2006   85         3           NaN              55.0
# 2007   88         2           NaN              65.0
# 2008   85         2           NaN              55.0
# 2001   80         2          50.0               NaN
# 2002   85         3          52.0               NaN
# 2003   88         2          50.0               NaN
# 2004   85         2          53.0               NaN
# C:\Users\simra_000\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# ...

# %%
#APPENDING

df4=df1.append(df2)
print(df4)

# this means adding files end to end
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %%
df5=df1.append(df3)
print(df5)

#hence append and concatenation don't do much on their own
# Out:
#       HPI  Int_rate  Low_tier_HPI  US_GDP_Thousands
# 2001   80         2           NaN              50.0
# 2002   85         3           NaN              55.0
# 2003   88         2           NaN              65.0
# 2004   85         2           NaN              55.0
# 2001   80         2          50.0               NaN
# 2002   85         3          52.0               NaN
# 2003   88         2          50.0               NaN
# 2004   85         2          53.0               NaN
# C:\Users\simra_000\Anaconda3\lib\site-packages\pandas\core\frame.py:6201: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   sort=sort)

# %%
# using panda series
# series in pandas are nothing but like a coloumn of a excel sheet. they can store any type of data and they are similar to a 
# 1D array

s=pd.Series([80,2,5],index=['HPI','Int_rate','US_GDP_Thousands'])
df6=df1.append(s, ignore_index=True)
print(df6)

#this is not super efficient
# Out:
#    HPI  Int_rate  US_GDP_Thousands
# 0   80         2                50
# 1   85         3                55
# 2   88         2                65
# 3   85         2                55
# 4   80         2                 5

# %%
df1 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2001, 2002, 2003, 2004])

df2 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Int_rate':[2, 3, 2, 2],
                    'US_GDP_Thousands':[50, 55, 65, 55]},
                   index = [2005, 2006, 2007, 2008])

df3 = pd.DataFrame({'HPI':[80,85,88,85],
                    'Unemployment':[7, 8, 9, 6],
                    'Low_tier_HPI':[50, 52, 50, 53]},
                   index = [2001, 2002, 2003, 2004])

# %%
print(pd.merge(df1,df3, on='HPI'))
# Out:
#    HPI  Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# 0   80         2                50             7            50
# 1   85         3                55             8            52
# 2   85         3                55             6            53
# 3   85         2                55             8            52
# 4   85         2                55             6            53
# 5   88         2                65             9            50

# %%
print(pd.merge(df1,df2, on=['HPI','Int_rate']))
# Out:
#    HPI  Int_rate  US_GDP_Thousands_x  US_GDP_Thousands_y
# 0   80         2                  50                  50
# 1   85         3                  55                  55
# 2   88         2                  65                  65
# 3   85         2                  55                  55

# %%
df4 = pd.merge(df1,df3, on='HPI')
df4.set_index('HPI', inplace=True)
print(df4)
# Out:
#      Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# HPI
# 80          2                50             7            50
# 85          3                55             8            52
# 85          3                55             6            53
# 85          2                55             8            52
# 85          2                55             6            53
# 88          2                65             9            50

# %%
# Out:
#      Int_rate  US_GDP_Thousands  Unemployment  Low_tier_HPI
# HPI
# 80          2                50             7            50
# 85          3                55             8            52
# 85          3                55             6            53
# 85          2                55             8            52
# 85          2                55             6            53
# 88          2                65             9            50
